# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Loading a CSV file into a DataFrame:
df = pd.read_csv("/content/drive/MyDrive/globalterrorismdb_0718dist.csv",encoding =('ISO-8859-1'),low_memory =False)
#Renaming Columns
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type','weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)
#Selecting Specific Columns
df=df[['Year','Month','Day','Country','Region','city','latitude','longitude','AttackType','Killed','Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]
#Calculating Casualties:
df['casualities']=df['Killed']+df['Wounded']
#Displaying the First Three Rows:
df.head(3)
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
#
#             city   latitude   longitude                   AttackType  Killed  \
# 0  Santo Domingo  18.456792  -69.951164                Assassination     1.0
# 1    Mexico city  19.371887  -99.086624  Hostage Taking (Kidnapping)     0.0
# 2        Unknown  15.478598  120.599741                Assassination     1.0
#
#    Wounded                   Target Summary  \
# 0      0.0             Julio Guzman     NaN
# 1      0.0  Nadine Chaval, daughter     NaN
# 2      0.0                 Employee     NaN
#
#                                 Group                  Target_type  \
# 0                              MANO-D  Private Citizens & Property
# ...

# %%
#display the last 10 rows of the DataFrame
df.tail(10)
# Out:
#         Year  Month  Day      Country                      Region  \
# 181681  2017     12   31  Philippines              Southeast Asia
# 181682  2017     12   31        Italy              Western Europe
# 181683  2017     12   31  Afghanistan                  South Asia
# 181684  2017     12   31        India                  South Asia
# 181685  2017     12   31  Afghanistan                  South Asia
# 181686  2017     12   31      Somalia          Sub-Saharan Africa
# 181687  2017     12   31        Syria  Middle East & North Africa
# 181688  2017     12   31  Philippines              Southeast Asia
# 181689  2017     12   31        India                  South Asia
# 181690  2017     12   31  Philippines              Southeast Asia
#
#                      city   latitude   longitude  \
# 181681      Shariff Aguak   6.862806  124.443649
# 181682          Spinetoli  42.888982   13.772795
# 181683  Kohistan district  35.315467   64.815508
# ...

# %%
# Get the number of columns and their names
num_columns = len(df.columns)
column_names = df.columns.tolist()

# Get the shape of the dataset
shape = df.shape

# Display information
print('Number of columns:', num_columns)
print("--------------------------")
print("Total columns present in dataset:", column_names)
print("--------------------------")
print("Shape of Dataset:", shape)
# Out:
# Number of columns: 18
# --------------------------
# Total columns present in dataset: ['Year', 'Month', 'Day', 'Country', 'Region', 'city', 'latitude', 'longitude', 'AttackType', 'Killed', 'Wounded', 'Target', 'Summary', 'Group', 'Target_type', 'Weapon_type', 'Motive', 'casualities']
# --------------------------
# Shape of Dataset: (181691, 18)

# %%
df.info
# Out:
# <bound method DataFrame.info of         Year  Month  Day             Country                       Region  \
# 0       1970      7    2  Dominican Republic  Central America & Caribbean
# 1       1970      0    0              Mexico                North America
# 2       1970      1    0         Philippines               Southeast Asia
# 3       1970      1    0              Greece               Western Europe
# 4       1970      1    0               Japan                    East Asia
# ...      ...    ...  ...                 ...                          ...
# 181686  2017     12   31             Somalia           Sub-Saharan Africa
# 181687  2017     12   31               Syria   Middle East & North Africa
# 181688  2017     12   31         Philippines               Southeast Asia
# 181689  2017     12   31               India                   South Asia
# 181690  2017     12   31         Philippines               Southeast Asia
#
# ...

# %%
df.skew
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.skew of         Year  Month  Day             Country                       Region  \
# 0       1970      7    2  Dominican Republic  Central America & Caribbean
# 1       1970      0    0              Mexico                North America
# 2       1970      1    0         Philippines               Southeast Asia
# 3       1970      1    0              Greece               Western Europe
# 4       1970      1    0               Japan                    East Asia
# ...      ...    ...  ...                 ...                          ...
# 181686  2017     12   31             Somalia           Sub-Saharan Africa
# 181687  2017     12   31               Syria   Middle East & North Africa
# 181688  2017     12   31         Philippines               Southeast Asia
# 181689  2017     12   31               India                   South Asia
# 181690  2017     12   31         Philippines               Southeast Asia
#
# ...

# %%
df.dtypes
# Out:
# Year             int64
# Month            int64
# Day              int64
# Country         object
# Region          object
# city            object
# latitude       float64
# longitude      float64
# AttackType      object
# Killed         float64
# Wounded        float64
# Target          object
# Summary         object
# Group           object
# Target_type     object
# Weapon_type     object
# Motive          object
# casualities    float64
# dtype: object

# %%
# Count duplicate values and NULL values
num_duplicates = df.duplicated().sum()
num_nulls = df.isnull().sum()

# Display the counts
print("Total number of duplicate values found :-", num_duplicates)
print("Total number of NULL values found :-", num_nulls)
# Out:
# Total number of duplicate values found :- 9515
# Total number of NULL values found :- Year                0
# Month               0
# Day                 0
# Country             0
# Region              0
# city              434
# latitude         4556
# longitude        4557
# AttackType          0
# Killed          10313
# Wounded         16311
# Target            636
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# casualities     16874
# dtype: int64

# %%
df.describe()
# Out:
#                 Year          Month            Day       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           longitude         Killed        Wounded    casualities
# count  1.771340e+05  171378.000000  165380.000000  164817.000000
# mean  -4.586957e+02       2.403272       3.167668       5.296128
# std    2.047790e+05      11.545741      35.949392      42.069023
# min   -8.618590e+07       0.000000       0.000000       0.000000
# ...

# %%
selected_columns = ['Year', 'Country', 'Region', 'city', 'AttackType', 'Target_type', 'Group', 'Killed']
df = df[selected_columns]

# Displaying the first few rows
df.head()
# Out:
#    Year             Country                       Region           city  \
# 0  1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1  1970              Mexico                North America    Mexico city
# 2  1970         Philippines               Southeast Asia        Unknown
# 3  1970              Greece               Western Europe         Athens
# 4  1970               Japan                    East Asia        Fukouka
#
#                        AttackType                  Target_type  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                 Group  Killed
# 0                              MANO-D     1.0
# 1  23rd of September Communist League     0.0
# ...

# %%
# Displaying the total columns present in the dataset
print("Total columns present in dataset:", df.columns)

# Displaying the first few rows
df.head()
# Out:
# Total columns present in dataset: Index(['Year', 'Country', 'Region', 'city', 'AttackType', 'Target_type',
#        'Group', 'Killed'],
#       dtype='object')
#    Year             Country                       Region           city  \
# 0  1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1  1970              Mexico                North America    Mexico city
# 2  1970         Philippines               Southeast Asia        Unknown
# 3  1970              Greece               Western Europe         Athens
# 4  1970               Japan                    East Asia        Fukouka
#
#                        AttackType                  Target_type  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# ...

# %%
df.isnull().sum()
# Out:
# Year               0
# Country            0
# Region             0
# city             434
# AttackType         0
# Target_type        0
# Group              0
# Killed         10313
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Year           0
# Country        0
# Region         0
# city           0
# AttackType     0
# Target_type    0
# Group          0
# Killed         0
# dtype: int64

# %%
df.sort_values(by='Killed', ascending=False).head(10)
# Out:
#         Year        Country                      Region              city  \
# 133518  2014           Iraq  Middle East & North Africa            Tikrit
# 73126   2001  United States               North America     New York City
# 73127   2001  United States               North America     New York City
# 55934   1994         Rwanda          Sub-Saharan Africa            Gikoro
# 136283  2014           Iraq  Middle East & North Africa            Sinjar
# 133225  2014           Iraq  Middle East & North Africa            Badush
# 179671  2017        Somalia          Sub-Saharan Africa         Mogadishu
# 76347   2004          Nepal                  South Asia  Dhading district
# 136746  2014          Syria  Middle East & North Africa           Unknown
# 170198  2016          Syria  Middle East & North Africa           Palmyra
#
#                          AttackType                  Target_type  \
# 133518  Hostage Taking (Kidnapping)                     Military
# ...

# %%
year_attacks = df.groupby('Year').size().reset_index(name='count')

# %%
sns.lineplot(x='Year', y='count', data=year_attacks, color='blue')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.title("Terrorism Attacks Trends ")
plt.show()

# %%
plt.subplots(figsize=(30,10))
sns.countplot(x='Year', data=df,ec='red')
plt.xticks(rotation=90)
plt.xlabel("Year",fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.grid(True)
plt.show()

# %%
r_type = df['Region'].value_counts().reset_index()
print(r_type)
r_type.columns = ['region_name', 'count']
# Out:
#                           index  Region
# 0    Middle East & North Africa   48171
# 1                    South Asia   43887
# 2                 South America   17306
# 3            Sub-Saharan Africa   15937
# 4                Western Europe   15727
# 5                Southeast Asia   11961
# 6   Central America & Caribbean    8022
# 7                Eastern Europe    4973
# 8                 North America    3363
# 9                     East Asia     763
# 10                 Central Asia     558
# 11        Australasia & Oceania     276

# %%
az = sns.barplot(y='region_name', x='count', data=r_type, palette='viridis', edgecolor='black')
plt.grid(True)
plt.title("Number of Total Attacks in Each Region")
plt.ylabel('Region')
plt.xlabel('Number of Attacks')
plt.show()

# %%
top_10_country=df.Country.value_counts()[:10].to_frame().reset_index()
top_10_country
# Out:
#             index  Country
# 0            Iraq    23895
# 1        Pakistan    14108
# 2     Afghanistan    12223
# 3           India    11740
# 4        Colombia     7848
# 5     Philippines     6694
# 6            Peru     5457
# 7  United Kingdom     5065
# 8          Turkey     4160
# 9     El Salvador     3939

# %%
top_10_country.columns = ['country_name', 'count']

# %%
top_10_country
# Out:
#      country_name  count
# 0            Iraq  23895
# 1        Pakistan  14108
# 2     Afghanistan  12223
# 3           India  11740
# 4        Colombia   7848
# 5     Philippines   6694
# 6            Peru   5457
# 7  United Kingdom   5065
# 8          Turkey   4160
# 9     El Salvador   3939

# %%
plt.figure(figsize=(15,5))
ay = sns.barplot(data=top_10_country, x='country_name', y='count', palette='viridis')
plt.grid(True)
plt.title('Top 10 Countries with the Most Attacks', fontsize=30)
plt.xlabel('Country', fontsize=20)
plt.ylabel('Count', fontsize=20)

for p in ay.patches:
    ay.annotate(format(p.get_height(), '.2f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 10), textcoords='offset points')

plt.show()

# %%
top_10_country_kill = df.groupby('Country')['Killed'].sum().nlargest(10).reset_index()
top_10_country_kill
# Out:
#        Country   Killed
# 0         Iraq  78567.0
# 1  Afghanistan  39137.0
# 2     Pakistan  23811.0
# 3      Nigeria  22682.0
# 4        India  19341.0
# 5    Sri Lanka  15530.0
# 6        Syria  15205.0
# 7     Colombia  14698.0
# 8         Peru  12771.0
# 9  El Salvador  12053.0

# %%
plt.figure(figsize=(10, 5))
ax = sns.barplot(y='Killed', x='Country', data=top_10_country_kill, palette='viridis', edgecolor='black')
plt.xlabel('Name of the Country')
plt.ylabel('Number of people Killed')
plt.grid(True)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 10), textcoords='offset points')

plt.show()

# %%
df.Region.value_counts()
# Out:
# Middle East & North Africa     48171
# South Asia                     43887
# South America                  17306
# Sub-Saharan Africa             15937
# Western Europe                 15727
# Southeast Asia                 11961
# Central America & Caribbean     8022
# Eastern Europe                  4973
# North America                   3363
# East Asia                        763
# Central Asia                     558
# Australasia & Oceania            276
# Name: Region, dtype: int64

# %%
data_south_asia = df[df['Region'] == 'South Asia'].head()
data_south_asia
# Out:
#       Year      Country      Region       city         AttackType  \
# 585   1970     Pakistan  South Asia    Karachi      Assassination
# 1186  1972        India  South Asia  New Delhi          Hijacking
# 1863  1973  Afghanistan  South Asia      Kabul            Unknown
# 2217  1974     Pakistan  South Asia    Karachi  Bombing/Explosion
# 2705  1974     Pakistan  South Asia   Peshawar  Bombing/Explosion
#
#                   Target_type              Group  Killed
# 585   Government (Diplomatic)            Unknown     4.0
# 1186      Airports & Aircraft       Palestinians     0.0
# 1863      Airports & Aircraft     Black December     0.0
# 2217                 Maritime  Muslim Guerrillas     0.0
# 2705  Government (Diplomatic)            Unknown     0.0

# %%
data_south_asia.Country.count()
data_ind_pak_afg=data_south_asia

# %%
data_ind_pak_afg = data_ind_pak_afg[(data_ind_pak_afg.Country=='Pakistan') | (data_ind_pak_afg.Country=='Afghanistan') | (data_ind_pak_afg.Country=='India')]
data_ind_pak_afg.head()
# Out:
#       Year      Country      Region       city         AttackType  \
# 585   1970     Pakistan  South Asia    Karachi      Assassination
# 1186  1972        India  South Asia  New Delhi          Hijacking
# 1863  1973  Afghanistan  South Asia      Kabul            Unknown
# 2217  1974     Pakistan  South Asia    Karachi  Bombing/Explosion
# 2705  1974     Pakistan  South Asia   Peshawar  Bombing/Explosion
#
#                   Target_type              Group  Killed
# 585   Government (Diplomatic)            Unknown     4.0
# 1186      Airports & Aircraft       Palestinians     0.0
# 1863      Airports & Aircraft     Black December     0.0
# 2217                 Maritime  Muslim Guerrillas     0.0
# 2705  Government (Diplomatic)            Unknown     0.0

# %%
data_ind_pak_afg = data_south_asia[(data_south_asia['Country'].isin(['Pakistan', 'Afghanistan', 'India'])) & (data_south_asia['Year'] >= 1970)]

# %%
data_ind_pak_afg_count = data_ind_pak_afg.groupby(['Country', 'Year'])['Killed'].size().reset_index(name='Killed')

# %%
target_type_counts = df['Target_type'].value_counts().head()
target_type_counts.tolist()  # Convert counts to a list
target_type_counts.keys().tolist()  # Convert the keys to a list
# Out:
# ['Private Citizens & Property',
#  'Military',
#  'Police',
#  'Government (General)',
#  'Business']

# %%
plt.figure(figsize=(10,5))
col=['green','purple','red','black','brown','orange']
plt.bar(list(df['Target_type'].value_counts().head().keys()),list(df['Target_type'].value_counts().head()),color=col,ec='black')
plt.grid(True)
plt.xlabel('Name of the Target',fontsize=11)
plt.ylabel('Number of Attacks',fontsize=11)


plt.show()

# %%
year = df.groupby('Year').size().reset_index(name='count')
year
# Out:
#     Year  count
# 0   1970    609
# 1   1971    407
# 2   1972    524
# 3   1973    424
# 4   1974    523
# 5   1975    587
# 6   1976    814
# 7   1977   1189
# 8   1978   1373
# 9   1979   2257
# 10  1980   2211
# 11  1981   1928
# 12  1982   1742
# 13  1983   1974
# 14  1984   2805
# 15  1985   2475
# 16  1986   2481
# 17  1987   3089
# 18  1988   3689
# 19  1989   4290
# 20  1990   3881
# 21  1991   4579
# 22  1992   5048
# 23  1994   3368
# 24  1995   3076
# 25  1996   3001
# 26  1997   3130
# 27  1998    871
# 28  1999   1345
# 29  2000   1757
# 30  2001   1885
# 31  2002   1321
# 32  2003   1258
# 33  2004   1151
# 34  2005   1999
# 35  2006   2619
# 36  2007   3171
# 37  2008   4649
# 38  2009   4551
# 39  2010   4757
# 40  2011   5002
# 41  2012   8314
# 42  2013  11685
# 43  2014  15881
# 44  2015  14160
# 45  2016  12809
# 46  2017  10285

# %%
year = year.sort_values(by='count', ascending=False).head()
year
# Out:
#     Year  count
# 43  2014  15881
# 44  2015  14160
# 45  2016  12809
# 42  2013  11685
# 46  2017  10285

# %%
list(year['Year'])
# Out:
# [2014, 2015, 2016, 2013, 2017]

# %%
# Grouping by Year and counting the number of entries
year = df.groupby(['Year']).size().reset_index(name='Count')

# Sorting the top 5 years with the most occurrences
year = year.sort_values(by='Count', ascending=False).head()

# Plotting a bar graph
plt.figure(figsize=(10,5))
colors = ['pink', 'orange', 'blue', 'yellow', 'red']
plt.bar(list(year['Year']), list(year['Count']), color=colors, edgecolor='black')
plt.xlabel('Year')
plt.ylabel('Number of Occurrences')
plt.grid(True)
plt.show()

# %%
plt.subplots(figsize=(15, 6))
sns.countplot(x='AttackType', data=df, palette='viridis', order=df['AttackType'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Attacking Methods by Terrorists')
plt.show()
